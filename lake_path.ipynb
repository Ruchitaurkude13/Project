# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Out:
# StatementMeta(, bcd0e61b-53b7-41bc-bc9f-1e7143ea13ee, 4, Finished, Available, Finished)

# %%
#Lake House Paths  
 
injection_lh_fpath = r"abfss://FabricTrainingWorkspace@onelake.dfs.fabric.microsoft.com/staging_lake_RU.Lakehouse/Files"
bronz_lh_fpath = r"abfss://FabricTrainingWorkspace@onelake.dfs.fabric.microsoft.com/bronze_lake_RU.Lakehouse/Files"
silver_lh_fpath = r"abfss://FabricTrainingWorkspace@onelake.dfs.fabric.microsoft.com/silver_lake_RU.Lakehouse/Files"
gold_lh_fpath = r"abfss://FabricTrainingWorkspace@onelake.dfs.fabric.microsoft.com/gold_lake_RU.Lakehouse/Files"
silver_delta_table = r"abfss://FabricTrainingWorkspace@onelake.dfs.fabric.microsoft.com/silver_lake_RU.Lakehouse/Tables"
Fact = "rabfss://FabricTrainingWorkspace@onelake.dfs.fabric.microsoft.com/Fact_RU.Lakehouse/Tables"
# Out:
# StatementMeta(, bcd0e61b-53b7-41bc-bc9f-1e7143ea13ee, 5, Finished, Available, Finished)
